# %%
pip install tiktoken
# Out:
# ...
#   Using cached tiktoken-0.13.0-cp311-cp311-win_amd64.whl (876 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tiktoken
print(tiktoken.__version__)
# Out:
# 0.13.0

# %%
encodemodel = tiktoken.encoding_for_model("gpt-4o")
text = "I Love You Baby"
x = encodemodel.encode(text)
print(x)
# Out:
# [40, 13007, 1608, 24086]

# %%
y = encodemodel.decode([40, 13007, 1608, 24086])
print(y)
# Out:
# I Love You Baby
